# %%
import pandas as pd

df = pd.read_csv(
    '/content/datatran2026.csv',
    sep=';',
    encoding='Latin1'
)

df.head()
# Out:
#        id data_inversa    dia_semana   horario  uf   br     km  municipio  \
# 0  742921   01/01/2026  quinta-feira  04:04:00  TO  153    155  ARAGUAINA
# 1  742942   01/01/2026  quinta-feira  06:40:00  MG  262  146,1  RIO CASCA
# 2  742943   01/01/2026  quinta-feira  06:58:00  SC  101    193    BIGUACU
# 3  742947   01/01/2026  quinta-feira  07:05:00  DF   60     23   BRASILIA
# 4  742960   01/01/2026  quinta-feira  06:17:00  MT  163   1044     MATUPA
#
#                              causa_acidente                  tipo_acidente  \
# 0  Objeto estático sobre o leito carroçável                     Tombamento
# 1                         Condutor Dormindo                Colisão frontal
# 2  Reação tardia ou ineficiente do condutor  Colisão lateral mesmo sentido
# 3  Reação tardia ou ineficiente do condutor               Colisão traseira
# 4                    Transitar na contramão                Colisão frontal
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.shape
# Out:
# (29774, 30)

# %%
df.columns
# Out:
# Index(['id', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br', 'km',
#        'municipio', 'causa_acidente', 'tipo_acidente',
#        'classificacao_acidente', 'fase_dia', 'sentido_via',
#        'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo',
#        'pessoas', 'mortos', 'feridos_leves', 'feridos_graves', 'feridos',
#        'ilesos', 'ignorados', 'veiculos', 'latitude', 'longitude', 'regional',
#        'delegacia', 'uop'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29774 entries, 0 to 29773
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      29774 non-null  int64
#  1   data_inversa            29774 non-null  object
#  2   dia_semana              29774 non-null  object
#  3   horario                 29774 non-null  object
#  4   uf                      29774 non-null  object
#  5   br                      29774 non-null  int64
#  6   km                      29774 non-null  object
#  7   municipio               29774 non-null  object
#  8   causa_acidente          29774 non-null  object
#  9   tipo_acidente           29774 non-null  object
#  10  classificacao_acidente  29773 non-null  object
#  11  fase_dia                29774 non-null  object
#  12  sentido_via             29774 non-null  object
#  13  condicao_metereologica  29774 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# data_inversa               0
# dia_semana                 0
# horario                    0
# uf                         0
# br                         0
# km                         0
# municipio                  0
# causa_acidente             0
# tipo_acidente              0
# classificacao_acidente     1
# fase_dia                   0
# sentido_via                0
# condicao_metereologica     0
# tipo_pista                 0
# tracado_via                0
# uso_solo                   0
# pessoas                    0
# mortos                     0
# feridos_leves              0
# feridos_graves             0
# feridos                    0
# ilesos                     0
# ignorados                  0
# veiculos                   0
# latitude                   0
# longitude                  0
# regional                  17
# delegacia                 24
# uop                       33
# dtype: int64

# %%
print(f'total de acidentes de transito registrados:{len(df)}')
# Out:
# total de acidentes de transito registrados:29774

# %%
df['uf'].value_counts().head(10)
# Out:
# uf
# MG    3756
# SC    3538
# PR    3254
# RJ    2644
# RS    1911
# SP    1832
# BA    1712
# GO    1395
# PE    1361
# MT    1066
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


df['uf'].value_counts().head(10).plot(kind='bar')

plt.title('top 10 estados com mais acidentes')
plt.xlabel("estados")
plt.ylabel("Qauantidade de acidentes")
plt.xticks(rotation = 0)

plt.show()

# %%
df['tipo_acidente'].value_counts().head(10)
# Out:
# tipo_acidente
# Colisão traseira                  5941
# Saída de leito carroçável         4299
# Colisão transversal               3838
# Colisão lateral mesmo sentido     3284
# Tombamento                        2616
# Colisão com objeto                2050
# Colisão frontal                   1882
# Queda de ocupante de veículo      1444
# Atropelamento de Pedestre         1191
# Colisão lateral sentido oposto     888
# Name: count, dtype: int64

# %%
df['causa_acidente'].value_counts().head(10)
# Out:
# causa_acidente
# Ausência de reação do condutor                               4721
# Reação tardia ou ineficiente do condutor                     4463
# Acessar a via sem observar a presença dos outros veículos    2906
# Condutor deixou de manter distância do veículo da frente     1779
# Velocidade Incompatível                                      1632
# Manobra de mudança de faixa                                  1579
# Ingestão de álcool pelo condutor                             1440
# Demais falhas mecânicas ou elétricas                         1362
# Transitar na contramão                                       1012
# Condutor Dormindo                                             777
# Name: count, dtype: int64

# %%
df['fase_dia'].value_counts()
# Out:
# fase_dia
# Pleno dia      16753
# Plena Noite    10041
# Anoitecer       1562
# Amanhecer       1418
# Name: count, dtype: int64

# %%
print(f'mortos: {df['mortos'].sum()}')
# Out:
# mortos: 2429

# %%
print(f'feridos graves: {df['feridos_graves'].sum()}')
# Out:
# feridos graves: 8143

# %%
print(f'feridos leves: {df.feridos_leves.sum()}')
# Out:
# feridos leves: 26402
